# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("testset.csv",parse_dates=['datetime_utc'],skipinitialspace=True)

# %%
data['Date'] = pd.to_datetime(data['datetime_utc'])
data['year'] = data['Date'].dt.year
data['month'] = data['Date'].dt.month
data['day'] = data['Date'].dt.day
data['hour'] = data['Date'].dt.hour

# %% [markdown]
# # 1. Cleaning of data

# %%
data.fillna(0, inplace=False)
# Out:
#               datetime_utc              _conds  _dewptm  _fog  _hail  \
# 0      1996-11-01 11:00:00               Smoke      9.0     0      0
# 1      1996-11-01 12:00:00               Smoke     10.0     0      0
# 2      1996-11-01 13:00:00               Smoke     11.0     0      0
# 3      1996-11-01 14:00:00               Smoke     10.0     0      0
# 4      1996-11-01 16:00:00               Smoke     11.0     0      0
# 5      1996-11-01 17:00:00               Smoke     12.0     0      0
# 6      1996-11-01 18:00:00               Smoke     13.0     0      0
# 7      1996-11-01 19:00:00               Smoke     13.0     0      0
# 8      1996-11-01 20:00:00               Smoke     13.0     0      0
# 9      1996-11-01 21:00:00               Smoke     13.0     0      0
# 10     1996-11-01 22:00:00               Smoke     13.0     0      0
# 11     1996-11-01 23:00:00               Smoke     12.0     0      0
# 12     1996-11-02 00:00:00               Smoke     11.0     0      0
# ...

# %%
data=data.drop('_precipm',axis=1)

# %%
data.head()
# Out:
#          datetime_utc _conds  _dewptm  _fog  _hail  _heatindexm  _hum  \
# 0 1996-11-01 11:00:00  Smoke      9.0     0      0          NaN  27.0
# 1 1996-11-01 12:00:00  Smoke     10.0     0      0          NaN  32.0
# 2 1996-11-01 13:00:00  Smoke     11.0     0      0          NaN  44.0
# 3 1996-11-01 14:00:00  Smoke     10.0     0      0          NaN  41.0
# 4 1996-11-01 16:00:00  Smoke     11.0     0      0          NaN  47.0
#
#    _pressurem  _rain  _snow  ...  _wdird  _wdire  _wgustm  _windchillm  \
# 0      1010.0      0      0  ...   280.0    West      NaN          NaN
# 1     -9999.0      0      0  ...     0.0   North      NaN          NaN
# 2     -9999.0      0      0  ...     0.0   North      NaN          NaN
# 3      1010.0      0      0  ...     0.0   North      NaN          NaN
# 4      1011.0      0      0  ...     0.0   North      NaN          NaN
#
#    _wspdm                Date  year  month  day hour
# 0     7.4 1996-11-01 11:00:00  1996     11    1   11
# ...

# %% [markdown]
# # 2. linear plot

# %%
year_humi = data.groupby(data.year).mean()
fig,axes = plt.subplots(nrows=5,ncols=3,figsize=(20,30))
fig.subplots_adjust(hspace=0.5)
year_humi['_hum'].plot(ax = axes[0,0])
axes[0,0].set_title("humidity")
year_humi['_rain'].plot(ax = axes[0,1])
axes[0,1].set_title("Rain")
year_humi['_dewptm'].plot(ax = axes[0,2])
axes[0,2].set_title("Dew ")
year_humi['_pressurem'].plot(ax = axes[1,0])
axes[1,0].set_title("Pressure")
year_humi['_fog'].plot(ax = axes[1,1])
axes[1,1].set_title("Fog")
year_humi['_hail'].plot(ax = axes[1,2])
axes[1,2].set_title("Hail")
year_humi['_heatindexm'].plot(ax = axes[2,0])
axes[2,0].set_title("Heat index")
year_humi['_snow'].plot(ax = axes[2,1])
axes[2,1].set_title("Snow")
year_humi['_tornado'].plot(ax = axes[2,2])
axes[2,2].set_title("Tornado")
year_humi['_vism'].plot(ax = axes[3,0])
axes[3,0].set_title("Vism")
year_humi['_wdird'].plot(ax = axes[3,1])
axes[3,1].set_title("Wind Direction")
year_humi['_wspdm'].plot(ax = axes[3,2])
axes[3,2].set_title("Wind Speed")
year_humi['_tempm'].plot(ax = axes[4,0])
axes[4,0].set_title("Temprature")
year_humi['_thunder'].plot(ax = axes[4,1])
axes[4,1].set_title("Thunder")
year_humi['_wgustm'].plot(ax = axes[4,2])
axes[4,2].set_title("wgustm")
# Out:
# Text(0.5, 1.0, 'wgustm')

# %% [markdown]
# # 3. Pie chart

# %%
act=["Haze",'Fog','Smoke','Mist','Shallow Fog']
colors=['r','g','b','grey','magenta']
slices=[]
for i in act:
    slices.append(len(data[(data['month']==1) & (data['_conds']==i) ]))
    
plt.pie(slices, labels=act,colors=colors,shadow=True,autopct="%1.1f%%",startangle=90)
plt.legend(loc=(1,1))
plt.title("january")
plt.show()

# %%
act=["Haze",'Clear','Smoke','Mist','Shallow Fog']
colors=['r','g','b','grey','magenta']
slices=[]
for i in act:
    slices.append(len(data[(data['month']==2) & (data['_conds']==i) ]))
    
plt.pie(slices, labels=act,colors=colors,shadow=True,autopct="%1.1f%%",startangle=90)
plt.legend(loc=(1,1))
plt.title("February")
plt.show()

# %%
act=["Haze",'Smoke','Mist']
colors=['y','g','b']
slices=[]
for i in act:
    slices.append(len(data[(data['month']==3) & (data['_conds']==i) ]))
    
plt.pie(slices, labels=act,colors=colors,shadow=True,autopct="%1.1f%%",startangle=90)
plt.legend(loc=(1,1))
plt.title("March")
plt.show()

# %%
act=["Haze",'Clear','Widespread Dust','Smoke']
colors=['r','y','grey','magenta']
slices=[]
for i in act:
    slices.append(len(data[(data['month']==4) & (data['_conds']==i) ]))
    
plt.pie(slices, labels=act,colors=colors,shadow=True,autopct="%1.1f%%",startangle=90)
plt.legend(loc=(1,1))
plt.title("April")
plt.show()

# %%
act=['Smoke','Widespread Dust','Smoke',"Haze",'Scatter Clouds','Clear','Partly Cloudy']
colors=['r','g','b','grey','magenta','brown','orange']
slices=[]
for i in act:
    slices.append(len(data[(data['month']==5) & (data['_conds']==i) ]))
    
plt.pie(slices, labels=act,colors=colors,shadow=True,autopct="%1.1f%%",startangle=90)
plt.legend(loc=(1,1))
plt.title("May")
plt.show()

# %%
act=["Haze",'Widespread Dust','Partly Cloudy']
colors=['r','grey','magenta']
slices=[]
for i in act:
    slices.append(len(data[(data['month']==6) & (data['_conds']==i) ]))
    
plt.pie(slices, labels=act,colors=colors,shadow=True,autopct="%1.1f%%",startangle=90)
plt.legend(loc=(1,1))
plt.title("June")
plt.show()

# %%
act=["Haze",'Light Rain','Mist']
colors=['r','g','y']
slices=[]
for i in act:
    slices.append(len(data[(data['month']==7) & (data['_conds']==i) ]))
    
plt.pie(slices, labels=act,colors=colors,shadow=True,autopct="%1.1f%%",startangle=90)
plt.legend(loc=(1,1))
plt.title("July")
plt.show()

# %%
act=["Haze",'Light Rain','Mist']
colors=['r','g','b']
slices=[]
for i in act:
    slices.append(len(data[(data['month']==8) & (data['_conds']==i) ]))
    
plt.pie(slices, labels=act,colors=colors,shadow=True,autopct="%1.1f%%",startangle=90)
plt.legend(loc=(1,1))
plt.title("August")
plt.show()

# %%
act=["Haze",'Mist']
colors=['g','magenta']
slices=[]
for i in act:
    slices.append(len(data[(data['month']==9) & (data['_conds']==i) ]))
    
plt.pie(slices, labels=act,colors=colors,shadow=True,autopct="%1.1f%%",startangle=90)
plt.legend(loc=(1,1))
plt.title("September")
plt.show()

# %%
act=["Haze",'Smoke','Mist']
colors=['r','grey','magenta']
slices=[]
for i in act:
    slices.append(len(data[(data['month']==10) & (data['_conds']==i) ]))
    
plt.pie(slices, labels=act,colors=colors,shadow=True,autopct="%1.1f%%",startangle=90)
plt.legend(loc=(1,1))
plt.title("October")
plt.show()

# %%
act=["Haze",'Smoke','Mist']
colors=['g','orange','magenta']
slices=[]
for i in act:
    slices.append(len(data[(data['month']==11) & (data['_conds']==i) ]))
    
plt.pie(slices, labels=act,colors=colors,shadow=True,autopct="%1.1f%%",startangle=90)
plt.legend(loc=(1,1))
plt.title("November")
plt.show()

# %%
act=["Haze",'Fog','Smoke','Mist','Shallow Fog','Partial Fog']
colors=['r','g','b','grey','magenta','pink']
slices=[]
for i in act:
    slices.append(len(data[(data['month']==12) & (data['_conds']==i) ]))
    
plt.pie(slices, labels=act,colors=colors,shadow=True,autopct="%1.1f%%",startangle=90)
plt.legend(loc=(1,1))
plt.title("December")
plt.show()
